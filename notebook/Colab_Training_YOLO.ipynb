# %% [markdown]
# # Custom YOLO License Plate Training
# Run this notebook in Google Colab with a GPU runtime to train your custom license plate detector.

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install ultralytics roboflow

# %% [markdown]
# ## 2. Download Dataset from Roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="8joVH7TL2k5V6uScFBEy")
project = rf.workspace("moin").project("car_license_plates")
version = project.version(2)
dataset = version.download("yolov8")

print("Dataset downloaded to:", dataset.location)

# %% [markdown]
# ## 3. Train the YOLO Model

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8 nano model (fastest)
# Note: ultralytics supports YOLOv8 out of the box, which is extremely stable and accurate.
model = YOLO('yolov8n.pt')

# Train the model on your custom dataset
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,       # Adjust epochs based on how much the loss improves
    imgsz=640,
    batch=16,
    project="runs/detect",
    name="custom_license_plates"
)

print("\nTraining complete! Weights saved to: runs/detect/custom_license_plates/weights/best.pt")

# %% [markdown]
# ## 4. Download the Trained Weights
# Run this cell to download your new `best.pt` file to your local computer.

# %%
from google.colab import files
files.download('runs/detect/custom_license_plates/weights/best.pt')
